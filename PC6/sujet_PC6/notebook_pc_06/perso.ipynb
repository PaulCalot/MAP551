# %%
import numpy as np
import matplotlib.pyplot as plt

def f(X, t):
    x1, x2 = X
    return [x2, 1-x1**2]

x1 = np.linspace(-3.0, 2.0, 30)
x2 = np.linspace(-3.0, 3.0, 30)

X1, X2 = np.meshgrid(x1, x2)

t = 0

u, v = np.zeros(X1.shape), np.zeros(X2.shape)

NI, NJ = X1.shape

for i in range(NI):
    for j in range(NJ):
        x1 = X1[i, j]
        x2 = X2[i, j]
        yprime = f([x1, x2], t)
        u[i,j] = yprime[0]
        v[i,j] = yprime[1]
     
    
f_ = lambda x : np.sqrt(abs(2*(x-x**3/3+2/3)))
x1_ = np.linspace(-5.0, 2.0, 100)
x2_ = f_(x1_)
x2__ = -x2_

fig, ax = plt.subplots(figsize = (15,10))
Q = plt.quiver(X1, X2, u, v, color='r', width = 0.001) # scale = 300
plt.xlabel('$x_1$')
plt.ylabel('$x_2$')
plt.xlim([-3, 2])
plt.ylim([-3,3])

# plotting the pahse portrait
plt.plot(x1_,x2_, color = 'blue')
plt.plot(x1_,x2__, color = 'blue')

m
plt.savefig('phase-portrait.png', dpi = 300)

# %%
alpha = -1 # 1

def f(X, t):
    x1, x2 = X
    return [-x1, alpha*x2**3]


x1 = np.linspace(-1.5, 1.5, 30)
x2 = np.linspace(-2.0, 2, 30)

X1, X2 = np.meshgrid(x1, x2)

t = 0

u, v = np.zeros(X1.shape), np.zeros(X2.shape)

NI, NJ = X1.shape

for i in range(NI):
    for j in range(NJ):
        x1 = X1[i, j]
        x2 = X2[i, j]
        yprime = f([x1, x2], t)
        u[i,j] = yprime[0]
        v[i,j] = yprime[1]
     
    
    
fig, ax = plt.subplots(figsize = (15,10))
Q = plt.quiver(X1, X2, u, v, color='r', width = 0.001) # scale = 300
plt.xlabel('$x_1$')
plt.ylabel('$x_2$')
plt.xlim([-1.5, 1.5])
plt.ylim([-2, 2])

x2_f = lambda t : 1/np.sqrt(1-2*alpha*t)
x1_f = lambda t : np.exp(-t)
T = np.linspace(-100, 100, 2000)
x1_ = x1_f(T)
x2_ = x2_f(T)

# plotting the pahse portrait
plt.plot(x1_,x2_, color = 'blue')
plt.plot(-x1_,x2_, color = 'blue')
plt.plot(x1_,-x2_, color = 'blue')
plt.plot(-x1_,-x2_, color = 'blue')

plt.savefig('phase-portrait.png', dpi = 300)

# %%
from mpl_toolkits.mplot3d import Axes3D  # noqa: F401 unused import

import matplotlib.pyplot as plt
from matplotlib import cm
from matplotlib.ticker import LinearLocator, FormatStrFormatter
import numpy as np




det = lambda a,b : a**2
tr = lambda a,b : b-1-a**2

def f(a,b):
    return 4*det(a,b)-tr(a,b)**2

# plotting the function

A = np.linspace(0,2,100)
B = np.linspace(0,3,100)
A_,B_ = np.meshgrid(A,B)

t = 0
Z = np.zeros(A_.shape)

NI, NJ = A_.shape

for i in range(NI):
    for j in range(NJ):
        a = A_[i, j]
        b = B_[i, j]
        c = f(a,b)
        Z[i,j] = c

fig = plt.figure()
ax = fig.gca(projection='3d')
surf = ax.plot_surface(A_, B_, Z, cmap=cm.coolwarm,
                       linewidth=0, antialiased=False)
fig.colorbar(surf, shrink=0.5, aspect=5)
ax.set_xlabel('$a$')
ax.set_ylabel('$b$')
plt.savefig("3D_graph.png", dpi = 400)
plt.show()

# %%
def g(theta,Fk):
    return fk*np.exp(theta)-theta

Fk_max = 10
Fk = [k*0.1 for k in range(0,Fk_max)]
theta = np.linspace(0, 5, 100)

L = []

for k in range(Fk_max):
    fk = Fk[k]
    L.append(fk*np.exp(theta)-theta)

fig, ax = plt.subplots(figsize = (10,10))

for k in range(Fk_max):
    plt.plot(theta, L[k], label="$F_k$ = {}".format(round(Fk[k],1)))
ax.set_xlabel('$x$')
ax.set_ylabel('$g(x) = F_k e^(x) - x$')
plt.legend(loc='best')
plt.savefig("evolution_as_fn_fk.png")
plt.show()
